# %% [markdown]
# # Train and Host a Keras Sequential Model
#
# This notebook shows how to train and host a Keras Sequential model on SageMaker. The model used for this notebook is a simple deep CNN that was extracted from [the Keras examples](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py).

# %% [markdown]
# ## The dataset
# The [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html) is one of the most popular machine learning datasets. It consists of 60,000 32x32 images belonging to 10 different classes (6,000 images per class). Here are the classes in the dataset, as well as 10 random images from each:
#
# ![cifar10](https://maet3608.github.io/nuts-ml/_images/cifar10.png)
#
# In this tutorial, we will train a deep CNN to recognize these images.

# %% [markdown]
# ## Set up the environment

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Download the CIFAR-10 dataset
# Downloading the test and training data will take around 5 minutes.

# %%
import utils

utils.cifar10_download()
# Out:
# FloatProgress(value=0.0)
# >> Downloading cifar-10-binary.tar.gz
# Successfully downloaded cifar-10-binary.tar.gz 170052171 bytes.

# %% [markdown]
# ## Upload the dataset to an S3 bucket

# %%
inputs = sagemaker_session.upload_data(path='/tmp/cifar10_data', key_prefix='data/DEMO-cifar10')

# %% [markdown]
# `sagemaker_session.upload_data` will upload the CIFAR-10 dataset from this machine to a bucket named **sagemaker-{region}-{*your aws account number*}**, if you don't have this bucket yet, `sagemaker_session` will create it for you.

# %% [markdown]
# ## Complete source code
# Here is the full source code for the model:

# %%
# !cat cifar10_cnn.py
# Out:
# #     Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# #     Licensed under the Apache License, Version 2.0 (the "License").
# #     You may not use this file except in compliance with the License.
# #     A copy of the License is located at
# #
# #         https://aws.amazon.com/apache-2-0/
# #
# #     or in the "license" file accompanying this file. This file is distributed
# #     on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either
# #     express or implied. See the License for the specific language governing
# #     permissions and limitations under the License.
#
# from __future__ import absolute_import
# from __future__ import division
# from __future__ import print_function
#
# import os
#
# import tensorflow as tf
# from tensorflow.python.keras.layers import InputLayer, Conv2D, Activation, MaxPooling2D, Dropout, Flatten, Dense
# from tensorflow.python.keras.models import Sequential
# from tensorflow.python.keras.optimizers import RMSprop
# from tensorflow.python.saved_model.signature_constants import PREDICT_INPUTS
#
# HEIGHT = 32
# WIDTH = 32
# DEPTH = 3
# NUM_CLASSES = 10
# NUM_DATA_BATCHES = 5
# NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN = 10000 * NUM_DATA_BATCHES
# BATCH_SIZE = 128
#
#
# def keras_model_fn(hyperparameters):
#     """keras_model_fn receives hyperparameters from the training job and returns a compiled keras model.
#     The model will be transformed into a TensorFlow Estimator before training and it will be saved in a
#     TensorFlow Serving SavedModel at the end of training.
#
#     Args:
#         hyperparameters: The hyperparameters passed to the SageMaker TrainingJob that runs your TensorFlow
#                          training script.
#     Returns: A compiled Keras model
#     """
#     model = Sequential()
#
#     # TensorFlow Serving default prediction input tensor name is PREDICT_INPUTS.
#     # We must conform to this naming scheme.
#     model.add(InputLayer(input_shape=(HEIGHT, WIDTH, DEPTH), name=PREDICT_INPUTS))
#     model.add(Conv2D(32, (3, 3), padding='same'))
#     model.add(Activation('relu'))
#     model.add(Conv2D(32, (3, 3)))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.25))
#
#     model.add(Conv2D(64, (3, 3), padding='same'))
#     model.add(Activation('relu'))
#     model.add(Conv2D(64, (3, 3)))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.25))
#
#     model.add(Flatten())
#     model.add(Dense(512))
#     model.add(Activation('relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(NUM_CLASSES))
#     model.add(Activation('softmax'))
#
#     _model = tf.keras.Model(inputs=model.input, outputs=model.output)
#
#     opt = RMSprop(lr=hyperparameters['learning_rate'], decay=hyperparameters['decay'])
#
#     _model.compile(loss='categorical_crossentropy',
#                   optimizer=opt,
#                   metrics=['accuracy'])
#
#     return _model
#
#
# def serving_input_fn(hyperparameters):
#     """This function defines the placeholders that will be added to the model during serving.
#     The function returns a tf.estimator.export.ServingInputReceiver object, which packages the
#     placeholders and the resulting feature Tensors together.
#     For more information: https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/README.rst#creating-a-serving_input_fn
#
#     Args:
#         hyperparameters: The hyperparameters passed to SageMaker TrainingJob that runs your TensorFlow
#                         training script.
#     Returns: ServingInputReceiver or fn that returns a ServingInputReceiver
#     """
#
#     # Notice that the input placeholder has the same input shape as the Keras model input
#     tensor = tf.placeholder(tf.float32, shape=[None, HEIGHT, WIDTH, DEPTH])
#
#     # The inputs key PREDICT_INPUTS matches the Keras InputLayer name
#     inputs = {PREDICT_INPUTS: tensor}
#     return tf.estimator.export.ServingInputReceiver(inputs, inputs)
#
#
# def train_input_fn(training_dir, hyperparameters):
#     """Returns input function that would feed the model during training"""
#     return _input(tf.estimator.ModeKeys.TRAIN,
#                     batch_size=BATCH_SIZE, data_dir=training_dir)
#
#
# def eval_input_fn(training_dir, hyperparameters):
#     """Returns input function that would feed the model during evaluation"""
#     return _input(tf.estimator.ModeKeys.EVAL,
#                     batch_size=BATCH_SIZE, data_dir=training_dir)
#
#
# def _input(mode, batch_size, data_dir):
#     """Uses the tf.data input pipeline for CIFAR-10 dataset.
#     Args:
#         mode: Standard names for model modes (tf.estimators.ModeKeys).
#         batch_size: The number of samples per batch of input requested.
#     """
#     dataset = _record_dataset(_filenames(mode, data_dir))
#
#     # For training repeat forever.
#     if mode == tf.estimator.ModeKeys.TRAIN:
#         dataset = dataset.repeat()
#
#     dataset = dataset.map(_dataset_parser)
#     dataset.prefetch(2 * batch_size)
#
#     # For training, preprocess the image and shuffle.
#     if mode == tf.estimator.ModeKeys.TRAIN:
#         dataset = dataset.map(_train_preprocess_fn)
#         dataset.prefetch(2 * batch_size)
#
#         # Ensure that the capacity is sufficiently large to provide good random
#         # shuffling.
#         buffer_size = int(NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN * 0.4) + 3 * batch_size
#         dataset = dataset.shuffle(buffer_size=buffer_size)
#
#     # Subtract off the mean and divide by the variance of the pixels.
#     dataset = dataset.map(
#         lambda image, label: (tf.image.per_image_standardization(image), label))
#     dataset.prefetch(2 * batch_size)
#
#     # Batch results by up to batch_size, and then fetch the tuple from the
#     # iterator.
#     iterator = dataset.batch(batch_size).make_one_shot_iterator()
#     images, labels = iterator.get_next()
#
#     # We must use the default input tensor name PREDICT_INPUTS
#     return {PREDICT_INPUTS: images}, labels
#
#
# def _train_preprocess_fn(image, label):
#     """Preprocess a single training image of layout [height, width, depth]."""
#     # Resize the image to add four extra pixels on each side.
#     image = tf.image.resize_image_with_crop_or_pad(image, HEIGHT + 8, WIDTH + 8)
#
#     # Randomly crop a [HEIGHT, WIDTH] section of the image.
#     image = tf.random_crop(image, [HEIGHT, WIDTH, DEPTH])
#
#     # Randomly flip the image horizontally.
#     image = tf.image.random_flip_left_right(image)
#
#     return image, label
#
#
# def _dataset_parser(value):
#     """Parse a CIFAR-10 record from value."""
#     # Every record consists of a label followed by the image, with a fixed number
#     # of bytes for each.
#     label_bytes = 1
#     image_bytes = HEIGHT * WIDTH * DEPTH
#     record_bytes = label_bytes + image_bytes
#
#     # Convert from a string to a vector of uint8 that is record_bytes long.
#     raw_record = tf.decode_raw(value, tf.uint8)
#
#     # The first byte represents the label, which we convert from uint8 to int32.
#     label = tf.cast(raw_record[0], tf.int32)
#
#     # The remaining bytes after the label represent the image, which we reshape
#     # from [depth * height * width] to [depth, height, width].
#     depth_major = tf.reshape(raw_record[label_bytes:record_bytes],
#                              [DEPTH, HEIGHT, WIDTH])
#
#     # Convert from [depth, height, width] to [height, width, depth], and cast as
#     # float32.
#     image = tf.cast(tf.transpose(depth_major, [1, 2, 0]), tf.float32)
#
#     return image, tf.one_hot(label, NUM_CLASSES)
#
#
# def _record_dataset(filenames):
#     """Returns an input pipeline Dataset from `filenames`."""
#     record_bytes = HEIGHT * WIDTH * DEPTH + 1
#     return tf.data.FixedLengthRecordDataset(filenames, record_bytes)
#
#
# def _filenames(mode, data_dir):
#     """Returns a list of filenames based on 'mode'."""
#     data_dir = os.path.join(data_dir, 'cifar-10-batches-bin')
#
#     assert os.path.exists(data_dir), ('Run cifar10_download_and_extract.py first '
#                                       'to download and extract the CIFAR-10 data.')
#
#     if mode == tf.estimator.ModeKeys.TRAIN:
#         return [
#             os.path.join(data_dir, 'data_batch_%d.bin' % i)
#             for i in range(1, NUM_DATA_BATCHES + 1)
#         ]
#     elif mode == tf.estimator.ModeKeys.EVAL:
#         return [os.path.join(data_dir, 'test_batch.bin')]
#     else:
#         raise ValueError('Invalid mode: %s' % mode)

# %% [markdown]
# Lets take a closer look:
#
# ### The model function
# This function constitutes the main difference between TensorFlow and Keras models on SageMaker; Keras models have a `keras_model_fn`:

# %%
def keras_model_fn(hyperparameters):
    model = Sequential()

    model.add(InputLayer(input_shape=(HEIGHT, WIDTH, DEPTH), name=PREDICT_INPUTS))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(NUM_CLASSES))
    model.add(Activation('softmax'))
    
    _model = tf.keras.Model(inputs=model.input, outputs=model.output)

    opt = RMSprop(lr=hyperparameters['learning_rate'], decay=hyperparameters['decay'])

    _model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])

    return _model

# %% [markdown]
# This function builds and returns a compiled Keras model.
#
# **Note:** The first layer is named `PREDICT_INPUTS`. This serves as a workaround for a known issue where TensorFlow does not recognize the default (or any custom) name for the first layer of Keras models. Furthermore, note that we are wrapping our model in a `tf.keras.Model` before returning it. This serves as a workaround for a known issue where a Sequential model cannot be directly converted into an Estimator. See [here](https://github.com/tensorflow/tensorflow/issues/20552) for more information about the issue.
#
# ### Input functions
# These functions are similar to those required by any other model using the TensorFlow Estimator API.

# %%
def serving_input_fn(params):
    # Notice that the input placeholder has the same input shape as the Keras model input
    tensor = tf.placeholder(tf.float32, shape=[None, HEIGHT, WIDTH, DEPTH])
    
    # The inputs key PREDICT_INPUTS matches the Keras InputLayer name
    inputs = {PREDICT_INPUTS: tensor}
    return tf.estimator.export.ServingInputReceiver(inputs, inputs)


def train_input_fn(training_dir, params):
    return _input(tf.estimator.ModeKeys.TRAIN,
                    batch_size=BATCH_SIZE, data_dir=training_dir)


def eval_input_fn(training_dir, params):
    return _input(tf.estimator.ModeKeys.EVAL,
                    batch_size=BATCH_SIZE, data_dir=training_dir)

# %% [markdown]
# The `train_` and `eval_` functions call the `_input` function which returns a properly processed and shuffled (for training) set of images and labels.
#
# ## Create a training job using the SageMaker TensorFlow Estimator

# %%
from sagemaker.tensorflow import TensorFlow

estimator = TensorFlow(entry_point='cifar10_cnn.py',
                       role=role,
                       framework_version='1.9',
                       hyperparameters={'learning_rate': 1e-4, 'decay':1e-6},
                       training_steps=1000, evaluation_steps=100,
                       train_instance_count=1, train_instance_type='ml.c4.xlarge')

estimator.fit(inputs)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-2018-09-04-04-00-38-673
# ....................
# 2018-09-04 04:03:47,758 INFO - root - running container entrypoint
# 2018-09-04 04:03:47,758 INFO - root - starting train task
# 2018-09-04 04:03:47,764 INFO - container_support.training - Training starting
# 2018-09-04 04:03:50,424 INFO - tf_container - ----------------------TF_CONFIG--------------------------
# 2018-09-04 04:03:50,424 INFO - tf_container - {"environment": "cloud", "cluster": {"master": ["algo-1:2222"]}, "task": {"index": 0, "type": "master"}}
# 2018-09-04 04:03:50,424 INFO - tf_container - ---------------------------------------------------------
# 2018-09-04 04:03:50,424 INFO - tf_container - creating RunConfig:
# 2018-09-04 04:03:50,424 INFO - tf_container - {'save_checkpoints_secs': 300}
# 2018-09-04 04:03:50,425 INFO - tensorflow - TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {u'master': [u'algo-1:2222']}, u'task': {u'index': 0, u'type': u'master'}}
# 2018-09-04 04:03:50,425 INFO - tf_container - invoking the user-provided keras_model_fn
# 2018-09-04 04:03:50,656 INFO - tensorflow - Using the Keras model provided.
# 2018-09-04 04:03:50,657 INFO - tensorflow - Using config: {'_save_checkpoints_secs': 300, '_global_id_in_cluster': 0, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': u'master', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f16a8a49c90>, '_model_dir': u's3://sagemaker-ap-northeast-1-075735992884/sagemaker-tensorflow-2018-09-04-04-00-38-673/checkpoints', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_service': None, '_device_fn': None, '_save_summary_steps': 100, '_num_ps_replicas': 0}
# 2018-09-04 04:03:50.663754: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2018-09-04 04:03:50.673103: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/config and using profilePrefix = 1
# 2018-09-04 04:03:50.673156: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/credentials and using profilePrefix = 0
# 2018-09-04 04:03:50.673191: I tensorflow/core/platform/s3/aws_logging.cc:54] Setting provider to read credentials from /root//.aws/credentials for credentials file and /root//.aws/config for the config file , for use with profile default
# 2018-09-04 04:03:50.673244: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating HttpClient with max connections2 and scheme http
# 2018-09-04 04:03:50.673282: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 2
# 2018-09-04 04:03:50.673323: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating TaskRole with default ECSCredentialsClient and refresh rate 900000
# 2018-09-04 04:03:50.673795: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/credentials for reading.
# 2018-09-04 04:03:50.673813: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-09-04 04:03:50.673825: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/config for reading.
# 2018-09-04 04:03:50.673835: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-09-04 04:03:50.673853: I tensorflow/core/platform/s3/aws_logging.cc:54] Credentials have expired or will expire, attempting to repull from ECS IAM Service.
# 2018-09-04 04:03:50.674021: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-09-04 04:03:50.674045: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:50.677845: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 25
# 2018-09-04 04:03:50.680178: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-09-04 04:03:50.680201: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:50.733138: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:03:50.733175: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:03:50.734414: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:51.695029: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:51.721873: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0403511536033831693
# 2018-09-04 04:03:51.733446: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.019915: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0403511536033831721
# 2018-09-04 04:03:52.023044: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.041317: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.284288: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.308733: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.346700: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0403521536033832308
# 2018-09-04 04:03:52.346894: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.371814: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.416256: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.441575: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.476046: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0403521536033832441
# 2018-09-04 04:03:52.476322: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.497008: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.542799: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.620914: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.633149: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:03:52.633177: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:03:52.633298: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.661021: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.759890: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0403521536033832660
# 2018-09-04 04:03:52.760192: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.778362: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.884908: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52,918 INFO - tensorflow - Skip starting Tensorflow server as there is only one node in the cluster.
# 2018-09-04 04:03:52.918528: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52.925522: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:03:52
# 2018-09-04 04:08:00,697 INFO - tensorflow - Evaluation [20/100]
# 2018-09-04 04:08:01,458 INFO - tensorflow - Evaluation [30/100]
# 2018-09-04 04:08:02,267 INFO - tensorflow - Evaluation [40/100]
# 2018-09-04 04:08:03,072 INFO - tensorflow - Evaluation [50/100]
# 2018-09-04 04:08:03,840 INFO - tensorflow - Evaluation [60/100]
# 2018-09-04 04:08:04,654 INFO - tensorflow - Evaluation [70/100]
# 2018-09-04 04:08:05,298 INFO - tensorflow - Finished evaluation at 2018-09-04-04:08:05
# 2018-09-04 04:08:05,298 INFO - tensorflow - Saving dict for global step 1000: accuracy = 0.42800632, global_step = 1000, loss = 1.5531522
# 2018-09-04 04:08:05.298659: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.372381: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.384248: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05,399 INFO - tensorflow - Saving 'checkpoint_path' summary for global step 1000: s3://sagemaker-ap-northeast-1-075735992884/sagemaker-tensorflow-2018-09-04-04-00-38-673/checkpoints/model.ckpt-1000
# 2018-09-04 04:08:05.400307: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.534296: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.551582: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.570279: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.585855: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:05.585888: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:05.586016: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.604707: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.615785: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:05.615817: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:05.615944: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.625264: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.637904: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:05.637935: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:05.638064: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.651545: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.660243: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:05.660273: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:05.660427: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.674505: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.699716: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408051536034085674
# 2018-09-04 04:08:05,708 INFO - tensorflow - Calling model_fn.
# 2018-09-04 04:08:05,805 INFO - tensorflow - Done calling model_fn.
# 2018-09-04 04:08:05,806 INFO - tensorflow - Signatures INCLUDED in export for Eval: None
# 2018-09-04 04:08:05,806 INFO - tensorflow - Signatures INCLUDED in export for Classify: None
# 2018-09-04 04:08:05,806 INFO - tensorflow - Signatures INCLUDED in export for Regress: None
# 2018-09-04 04:08:05,806 INFO - tensorflow - Signatures INCLUDED in export for Predict: ['serving_default']
# 2018-09-04 04:08:05,806 INFO - tensorflow - Signatures INCLUDED in export for Train: None
# 2018-09-04 04:08:05,832 INFO - tensorflow - Restoring parameters from s3://sagemaker-ap-northeast-1-075735992884/sagemaker-tensorflow-2018-09-04-04-00-38-673/checkpoints/model.ckpt-1000
# 2018-09-04 04:08:05.848803: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.877614: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.884526: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.902091: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.909358: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.926729: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.941887: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.962831: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.973133: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:05.990038: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.002321: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.029238: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.093191: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06,121 INFO - tensorflow - Assets added to graph.
# 2018-09-04 04:08:06,121 INFO - tensorflow - No assets to write.
# 2018-09-04 04:08:06.121982: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.133401: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:06.133438: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:06.133556: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.152827: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.161754: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:06.161785: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:06.161921: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.178270: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.186819: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:06.186845: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:06.186979: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.209851: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.237537: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408061536034086209
# 2018-09-04 04:08:06.270684: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.293017: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408061536034086270
# 2018-09-04 04:08:06.298277: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.408107: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408061536034086293
# 2018-09-04 04:08:06.409099: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.429291: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.537586: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.598937: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.640947: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408061536034086598
# 2018-09-04 04:08:06.641159: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.662180: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.701964: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.718235: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.739450: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408061536034086718
# 2018-09-04 04:08:06.739696: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.751118: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.762557: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.774336: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.788202: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.801771: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:06.817994: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.000843: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.021346: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.054050: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408071536034087021
# 2018-09-04 04:08:07.054245: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.071225: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.090668: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.139768: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.147941: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:07.147969: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:07.148110: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.186496: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.250705: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180904T0408071536034087186
# 2018-09-04 04:08:07,250 INFO - tensorflow - SavedModel written to: s3://sagemaker-ap-northeast-1-075735992884/sagemaker-tensorflow-2018-09-04-04-00-38-673/checkpoints/export/Servo/temp-1536034085/saved_model.pb
# 2018-09-04 04:08:07.251244: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.260821: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:07.260874: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:07.260997: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.276525: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.299866: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.325455: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.348571: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.410769: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.426733: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.454903: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.477965: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.604685: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.625554: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.662246: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.688887: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.700230: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:07.700264: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:07.700392: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.720862: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.729872: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-09-04 04:08:07.729903: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-09-04 04:08:07.730022: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07.744555: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-09-04 04:08:07,943 INFO - tf_container - Downloaded saved model at /opt/ml/model/export/Servo/1536034085/saved_model.pb
# Billable seconds: 379

# %% [markdown]
# **Note**: Keras models have a known issue and cannot be used for distributed (multi-instance) training. Keep `train_instance_count == 1` until the TensorFlow/Keras team support this feature. See [here](https://github.com/tensorflow/tensorflow/issues/14504) for more information about the issue.
#
#
# ## Deploy the trained model
#
# The deploy() method creates an endpoint which serves prediction requests in real-time.

# %%
predictor = estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-tensorflow-2018-09-04-04-00-38-673
# INFO:sagemaker:Creating endpoint with name sagemaker-tensorflow-2018-09-04-04-00-38-673
# ---------------------------------------------------------------!

# %% [markdown]
# ## Make some predictions
# Prediction is not the focus of this notebook, so to verify the endpoint's functionality, we'll simply generate random data in the correct shape and make a prediction.

# %%
# Creating fake prediction data
import numpy as np
data = np.random.randn(1, 32, 32, 3)

predictor.predict(data)
# Out:
# {'outputs': {'activation_5': {'dtype': 1,
#    'tensor_shape': {'dim': [{'size': 1}, {'size': 10}]},
#    'float_val': [0.009468553587794304,
#     0.2964172959327698,
#     0.0025624933186918497,
#     0.011709373444318771,
#     0.0044459146447479725,
#     0.004938485100865364,
#     0.06850682199001312,
#     0.040365345776081085,
#     0.001548273372463882,
#     0.5600374937057495]}},
#  'model_spec': {'name': 'generic_model',
#   'version': {'value': 1536034085},
#   'signature_name': 'serving_default'}}

# %% [markdown]
# # Cleaning up
# To avoid incurring charges to your AWS account for the resources used in this tutorial you need to delete the SageMaker Endpoint:

# %%
sagemaker.Session().delete_endpoint(predictor.endpoint)
# Out:
# INFO:sagemaker:Deleting endpoint with name: sagemaker-tensorflow-2018-09-04-04-00-38-673
